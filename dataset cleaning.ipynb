# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install seaborn
# Out:
# Requirement already satisfied: pandas in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.5.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (2.5.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Abarna\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from seaborn) (2.5.1)
# Requirement already satisfied: pandas>=1.2 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from seaborn) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Abarna\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=9 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: six>=1.5 in c:\Users\Abarna\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("atmosync_dataset.csv")

# %%
df.head()
# Out:
#    reading_id container_id commodity                   timestamp  \
# 0           1    CONT-0001   Avocado  2026-07-03 17:23:04.628550
# 1           2    CONT-0001   Avocado  2026-07-03 17:53:04.628550
# 2           3    CONT-0001   Avocado  2026-07-03 18:23:04.628550
# 3           4    CONT-0001   Avocado  2026-07-03 18:53:04.628550
# 4           5    CONT-0001   Avocado  2026-07-03 19:23:04.628550
#
#    hours_in_transit  temperature_c  humidity_pct  vibration_g  \
# 0               0.0           5.31         88.29        0.220
# 1               0.5           5.99         92.25        0.187
# 2               1.0           5.10         88.08        0.220
# 3               1.5           5.41         88.64        0.248
# 4               2.0           5.28         89.30        0.193
#
#    ideal_temp_min_c  ideal_temp_max_c  ...  quality_score  \
# 0                 4                 7  ...          99.98
# 1                 4                 7  ...          99.95
# 2                 4                 7  ...          99.93
# 3                 4                 7  ...          99.90
# 4                 4                 7  ...          99.88
#
#    shelf_life_hours_remaining  primary_price_per_kg_usd  \
# 0                      2041.8                     3.566
# 1                      2066.2                     3.564
# 2                      2040.8                     3.563
# 3                      2019.8                     3.562
# 4                      2060.8                     3.560
#
#    secondary_price_per_kg_usd primary_net_value_usd secondary_net_value_usd  \
# 0                       3.198              47306.56                42424.67
# 1                       3.197              47280.02                42411.40
# 2                       3.196              47266.76                42398.14
# 3                       3.195              47253.49                42384.87
# 4                       3.194              47226.96                42371.60
#
#   arbitrage_gain_usd  risk_status          recommended_action  \
# 0           -4881.89       Normal  Continue to Primary Market
# 1           -4868.62       Normal  Continue to Primary Market
# 2           -4868.62       Normal  Continue to Primary Market
# 3           -4868.62       Normal  Continue to Primary Market
# 4           -4855.36       Normal  Continue to Primary Market
#
#    cooling_unit_faulty
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
#
# [5 rows x 30 columns]

# %%
df.shape
# Out:
# (50000, 30)

# %%
df.describe()
# Out:
#          reading_id  hours_in_transit  temperature_c  humidity_pct  \
# count  50000.000000       50000.00000   50000.000000  50000.000000
# mean   25000.500000          24.59565       6.624175     89.974576
# std    14433.901067          14.43875       5.710725      3.228729
# min        1.000000           0.00000      -2.710000     73.840000
# 25%    12500.750000          12.00000       0.980000     87.870000
# 50%    25000.500000          24.50000       5.590000     90.190000
# 75%    37500.250000          37.00000      11.800000     92.300000
# max    50000.000000          49.50000      24.170000     99.000000
#
#         vibration_g  ideal_temp_min_c  ideal_temp_max_c  \
# count  50000.000000      50000.000000      50000.000000
# mean       0.170556          4.938820          7.346540
# std        0.188111          5.355794          5.583837
# min        0.000000         -1.000000          1.000000
# 25%        0.097000          0.000000          2.000000
# 50%        0.151000          4.000000          7.000000
# 75%        0.206000         10.000000         13.000000
# max        2.486000         13.000000         15.000000
#
#        ideal_humidity_min_pct  ideal_humidity_max_pct  temp_deviation_c  ...  \
# count            50000.000000             50000.00000      50000.000000  ...
# mean                87.213600                93.74220          0.391349  ...
# std                  2.483566                 2.16957          1.309178  ...
# min                 85.000000                90.00000          0.000000  ...
# 25%                 85.000000                90.00000          0.000000  ...
# 50%                 85.000000                95.00000          0.000000  ...
# 75%                 90.000000                95.00000          0.000000  ...
# max                 90.000000                95.00000          9.750000  ...
#
#        distance_primary_km  distance_secondary_km   quantity_kg  \
# count         50000.000000           50000.000000  50000.000000
# mean           1825.533000             664.623000  14088.139880
# std             283.521822             375.002041   3578.548053
# min            1400.000000             200.000000   8009.000000
# 25%            1600.000000             300.000000  10962.000000
# 50%            1800.000000             600.000000  14259.000000
# 75%            2100.000000             900.000000  17247.000000
# max            2300.000000            1400.000000  19965.000000
#
#        quality_score  shelf_life_hours_remaining  primary_price_per_kg_usd  \
# count   50000.000000                50000.000000              50000.000000
# mean       95.605646                 1600.255276                  2.981790
# std        12.127313                  776.474637                  1.487501
# min         0.000000                    0.000000                  0.000000
# 25%        97.340000                 1147.100000                  1.839000
# 50%        98.400000                 1703.300000                  2.833000
# 75%        99.220000                 2201.925000                  4.139000
# max        99.980000                 2853.200000                  6.416000
#
#        secondary_price_per_kg_usd  primary_net_value_usd  \
# count                50000.000000           50000.000000
# mean                     2.645452           41615.825001
# std                      1.311662           23481.561102
# min                      0.000000               0.000000
# 25%                      1.613000           23435.125000
# 50%                      2.519000           37010.970000
# 75%                      3.648000           54472.047500
# max                      5.832000          126614.880000
#
#        secondary_net_value_usd  arbitrage_gain_usd
# count             50000.000000        50000.000000
# mean              36916.919913        -4698.905087
# std               20729.788117         3302.703317
# min                   0.000000       -21938.430000
# 25%               21034.385000        -6533.730000
# 50%               32863.870000        -3988.250000
# 75%               48498.015000        -2508.800000
# max              109314.830000         7479.900000
#
# [8 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['reading_id', 'container_id', 'commodity', 'timestamp',
#        'hours_in_transit', 'temperature_c', 'humidity_pct', 'vibration_g',
#        'ideal_temp_min_c', 'ideal_temp_max_c', 'ideal_humidity_min_pct',
#        'ideal_humidity_max_pct', 'temp_deviation_c', 'humidity_deviation_pct',
#        'origin_port', 'primary_market', 'secondary_market',
#        'distance_primary_km', 'distance_secondary_km', 'quantity_kg',
#        'quality_score', 'shelf_life_hours_remaining',
#        'primary_price_per_kg_usd', 'secondary_price_per_kg_usd',
#        'primary_net_value_usd', 'secondary_net_value_usd',
#        'arbitrage_gain_usd', 'risk_status', 'recommended_action',
#        'cooling_unit_faulty'],
#       dtype='str')

# %%
df.dtypes
# Out:
# reading_id                      int64
# container_id                      str
# commodity                         str
# timestamp                         str
# hours_in_transit              float64
# temperature_c                 float64
# humidity_pct                  float64
# vibration_g                   float64
# ideal_temp_min_c                int64
# ideal_temp_max_c                int64
# ideal_humidity_min_pct          int64
# ideal_humidity_max_pct          int64
# temp_deviation_c              float64
# humidity_deviation_pct        float64
# origin_port                       str
# primary_market                    str
# secondary_market                  str
# distance_primary_km             int64
# distance_secondary_km           int64
# quantity_kg                     int64
# quality_score                 float64
# shelf_life_hours_remaining    float64
# primary_price_per_kg_usd      float64
# secondary_price_per_kg_usd    float64
# primary_net_value_usd         float64
# secondary_net_value_usd       float64
# arbitrage_gain_usd            float64
# risk_status                       str
# recommended_action                str
# cooling_unit_faulty              bool
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df =df.drop_duplicates()

# %%
df.isnull().sum()
# Out:
# reading_id                    0
# container_id                  0
# commodity                     0
# timestamp                     0
# hours_in_transit              0
# temperature_c                 0
# humidity_pct                  0
# vibration_g                   0
# ideal_temp_min_c              0
# ideal_temp_max_c              0
# ideal_humidity_min_pct        0
# ideal_humidity_max_pct        0
# temp_deviation_c              0
# humidity_deviation_pct        0
# origin_port                   0
# primary_market                0
# secondary_market              0
# distance_primary_km           0
# distance_secondary_km         0
# quantity_kg                   0
# quality_score                 0
# shelf_life_hours_remaining    0
# primary_price_per_kg_usd      0
# secondary_price_per_kg_usd    0
# primary_net_value_usd         0
# secondary_net_value_usd       0
# arbitrage_gain_usd            0
# risk_status                   0
# recommended_action            0
# cooling_unit_faulty           0
# dtype: int64

# %%
df.isnull().sum() / len(df) * 100
# Out:
# reading_id                    0.0
# container_id                  0.0
# commodity                     0.0
# timestamp                     0.0
# hours_in_transit              0.0
# temperature_c                 0.0
# humidity_pct                  0.0
# vibration_g                   0.0
# ideal_temp_min_c              0.0
# ideal_temp_max_c              0.0
# ideal_humidity_min_pct        0.0
# ideal_humidity_max_pct        0.0
# temp_deviation_c              0.0
# humidity_deviation_pct        0.0
# origin_port                   0.0
# primary_market                0.0
# secondary_market              0.0
# distance_primary_km           0.0
# distance_secondary_km         0.0
# quantity_kg                   0.0
# quality_score                 0.0
# shelf_life_hours_remaining    0.0
# primary_price_per_kg_usd      0.0
# secondary_price_per_kg_usd    0.0
# primary_net_value_usd         0.0
# secondary_net_value_usd       0.0
# arbitrage_gain_usd            0.0
# risk_status                   0.0
# recommended_action            0.0
# cooling_unit_faulty           0.0
# dtype: float64

# %%
df['ttimestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')

# %%
df['timestamp'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df['timestamp']
# Out:
# 0        2026-07-03 17:23:04.628550
# 1        2026-07-03 17:53:04.628550
# 2        2026-07-03 18:23:04.628550
# 3        2026-07-03 18:53:04.628550
# 4        2026-07-03 19:23:04.628550
#                     ...
# 49995    2026-07-04 21:23:45.058068
# 49996    2026-07-04 21:53:45.058068
# 49997    2026-07-04 22:23:45.058068
# 49998    2026-07-04 23:23:45.058068
# 49999    2026-07-04 23:53:45.058068
# Name: timestamp, Length: 50000, dtype: str

# %%
df.columns  = df.columns.str.strip().str.lower().str.replace( ' ','_')

# %%
df.rename(columns={'timestamp': 'Date_Time'}, inplace=True)

# %%
df.columns
# Out:
# Index(['reading_id', 'container_id', 'commodity', 'Date_Time',
#        'hours_in_transit', 'temperature_c', 'humidity_pct', 'vibration_g',
#        'ideal_temp_min_c', 'ideal_temp_max_c', 'ideal_humidity_min_pct',
#        'ideal_humidity_max_pct', 'temp_deviation_c', 'humidity_deviation_pct',
#        'origin_port', 'primary_market', 'secondary_market',
#        'distance_primary_km', 'distance_secondary_km', 'quantity_kg',
#        'quality_score', 'shelf_life_hours_remaining',
#        'primary_price_per_kg_usd', 'secondary_price_per_kg_usd',
#        'primary_net_value_usd', 'secondary_net_value_usd',
#        'arbitrage_gain_usd', 'risk_status', 'recommended_action',
#        'cooling_unit_faulty', 'ttimestamp'],
#       dtype='str')

# %%
df.head()
# Out:
#    reading_id container_id commodity                   Date_Time  \
# 0           1    CONT-0001   Avocado  2026-07-03 17:23:04.628550
# 1           2    CONT-0001   Avocado  2026-07-03 17:53:04.628550
# 2           3    CONT-0001   Avocado  2026-07-03 18:23:04.628550
# 3           4    CONT-0001   Avocado  2026-07-03 18:53:04.628550
# 4           5    CONT-0001   Avocado  2026-07-03 19:23:04.628550
#
#    hours_in_transit  temperature_c  humidity_pct  vibration_g  \
# 0               0.0           5.31         88.29        0.220
# 1               0.5           5.99         92.25        0.187
# 2               1.0           5.10         88.08        0.220
# 3               1.5           5.41         88.64        0.248
# 4               2.0           5.28         89.30        0.193
#
#    ideal_temp_min_c  ideal_temp_max_c  ...  shelf_life_hours_remaining  \
# 0                 4                 7  ...                      2041.8
# 1                 4                 7  ...                      2066.2
# 2                 4                 7  ...                      2040.8
# 3                 4                 7  ...                      2019.8
# 4                 4                 7  ...                      2060.8
#
#    primary_price_per_kg_usd  secondary_price_per_kg_usd  \
# 0                     3.566                       3.198
# 1                     3.564                       3.197
# 2                     3.563                       3.196
# 3                     3.562                       3.195
# 4                     3.560                       3.194
#
#    primary_net_value_usd secondary_net_value_usd arbitrage_gain_usd  \
# 0               47306.56                42424.67           -4881.89
# 1               47280.02                42411.40           -4868.62
# 2               47266.76                42398.14           -4868.62
# 3               47253.49                42384.87           -4868.62
# 4               47226.96                42371.60           -4855.36
#
#   risk_status          recommended_action  cooling_unit_faulty  \
# 0      Normal  Continue to Primary Market                False
# 1      Normal  Continue to Primary Market                False
# 2      Normal  Continue to Primary Market                False
# 3      Normal  Continue to Primary Market                False
# 4      Normal  Continue to Primary Market                False
#
#                   ttimestamp
# 0 2026-07-03 17:23:04.628550
# 1 2026-07-03 17:53:04.628550
# 2 2026-07-03 18:23:04.628550
# 3 2026-07-03 18:53:04.628550
# 4 2026-07-03 19:23:04.628550
#
# [5 rows x 31 columns]

# %%
df.ttimestamp.dropna(inplace=True)

# %%
df.columns
# Out:
# Index(['reading_id', 'container_id', 'commodity', 'Date_Time',
#        'hours_in_transit', 'temperature_c', 'humidity_pct', 'vibration_g',
#        'ideal_temp_min_c', 'ideal_temp_max_c', 'ideal_humidity_min_pct',
#        'ideal_humidity_max_pct', 'temp_deviation_c', 'humidity_deviation_pct',
#        'origin_port', 'primary_market', 'secondary_market',
#        'distance_primary_km', 'distance_secondary_km', 'quantity_kg',
#        'quality_score', 'shelf_life_hours_remaining',
#        'primary_price_per_kg_usd', 'secondary_price_per_kg_usd',
#        'primary_net_value_usd', 'secondary_net_value_usd',
#        'arbitrage_gain_usd', 'risk_status', 'recommended_action',
#        'cooling_unit_faulty', 'ttimestamp'],
#       dtype='str')

# %%
df.head()
# Out:
#    reading_id container_id commodity                   Date_Time  \
# 0           1    CONT-0001   Avocado  2026-07-03 17:23:04.628550
# 1           2    CONT-0001   Avocado  2026-07-03 17:53:04.628550
# 2           3    CONT-0001   Avocado  2026-07-03 18:23:04.628550
# 3           4    CONT-0001   Avocado  2026-07-03 18:53:04.628550
# 4           5    CONT-0001   Avocado  2026-07-03 19:23:04.628550
#
#    hours_in_transit  temperature_c  humidity_pct  vibration_g  \
# 0               0.0           5.31         88.29        0.220
# 1               0.5           5.99         92.25        0.187
# 2               1.0           5.10         88.08        0.220
# 3               1.5           5.41         88.64        0.248
# 4               2.0           5.28         89.30        0.193
#
#    ideal_temp_min_c  ideal_temp_max_c  ...  shelf_life_hours_remaining  \
# 0                 4                 7  ...                      2041.8
# 1                 4                 7  ...                      2066.2
# 2                 4                 7  ...                      2040.8
# 3                 4                 7  ...                      2019.8
# 4                 4                 7  ...                      2060.8
#
#    primary_price_per_kg_usd  secondary_price_per_kg_usd  \
# 0                     3.566                       3.198
# 1                     3.564                       3.197
# 2                     3.563                       3.196
# 3                     3.562                       3.195
# 4                     3.560                       3.194
#
#    primary_net_value_usd secondary_net_value_usd arbitrage_gain_usd  \
# 0               47306.56                42424.67           -4881.89
# 1               47280.02                42411.40           -4868.62
# 2               47266.76                42398.14           -4868.62
# 3               47253.49                42384.87           -4868.62
# 4               47226.96                42371.60           -4855.36
#
#   risk_status          recommended_action  cooling_unit_faulty  \
# 0      Normal  Continue to Primary Market                False
# 1      Normal  Continue to Primary Market                False
# 2      Normal  Continue to Primary Market                False
# 3      Normal  Continue to Primary Market                False
# 4      Normal  Continue to Primary Market                False
#
#                   ttimestamp
# 0 2026-07-03 17:23:04.628550
# 1 2026-07-03 17:53:04.628550
# 2 2026-07-03 18:23:04.628550
# 3 2026-07-03 18:53:04.628550
# 4 2026-07-03 19:23:04.628550
#
# [5 rows x 31 columns]
